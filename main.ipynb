# %%
import os
import pandas as pd

# Display data
for file in os.listdir('data'):
    df = pd.read_csv(f'data/{file}')
    print(file.upper() + ':')
    print(df, df.columns, '\n')
# Out:
# FEATURES.CSV:
#      feature_num  case_num                                       feature_text
# 0              0         0  Family-history-of-MI-OR-Family-history-of-myoc...
# 1              1         0                 Family-history-of-thyroid-disorder
# 2              2         0                                     Chest-pressure
# 3              3         0                              Intermittent-symptoms
# 4              4         0                                        Lightheaded
# ..           ...       ...                                                ...
# 138          912         9                        Family-history-of-migraines
# 139          913         9                                             Female
# 140          914         9                                        Photophobia
# 141          915         9                          No-known-illness-contacts
# 142          916         9                                   Subjective-fever
#
# [143 rows x 3 columns] Index(['feature_num', 'case_num', 'feature_text'], dtype='object')
#
# SAMPLE_SUBMISSION.CSV:
#           id         location
# 0  00016_000            0 100
# 1  00016_001              NaN
# 2  00016_002  200 250;300 400
# 3  00016_003              NaN
# 4  00016_004           75 110 Index(['id', 'location'], dtype='object')
#
# TRAIN.CSV:
#               id  case_num  pn_num  feature_num  \
# 0      00016_000         0      16            0
# 1      00016_001         0      16            1
# 2      00016_002         0      16            2
# 3      00016_003         0      16            3
# 4      00016_004         0      16            4
# ...          ...       ...     ...          ...
# 14295  95333_912         9   95333          912
# 14296  95333_913         9   95333          913
# 14297  95333_914         9   95333          914
# 14298  95333_915         9   95333          915
# 14299  95333_916         9   95333          916
#
#                                      annotation              location
# 0              ['dad with recent heart attcak']           ['696 724']
# 1                 ['mom with "thyroid disease']           ['668 693']
# 2                            ['chest pressure']           ['203 217']
# 3          ['intermittent episodes', 'episode']  ['70 91', '176 183']
# 4      ['felt as if he were going to pass out']           ['222 258']
# ...                                         ...                   ...
# 14295                                        []                    []
# 14296                                        []                    []
# 14297                              ['photobia']           ['274 282']
# 14298                      ['no sick contacts']           ['421 437']
# 14299                      ['Subjective fever']           ['314 330']
#
# [14300 rows x 6 columns] Index(['id', 'case_num', 'pn_num', 'feature_num', 'annotation', 'location'], dtype='object')
#
# TEST.CSV:
#           id  case_num  pn_num  feature_num
# 0  00016_000         0      16            0
# 1  00016_001         0      16            1
# 2  00016_002         0      16            2
# 3  00016_003         0      16            3
# 4  00016_004         0      16            4 Index(['id', 'case_num', 'pn_num', 'feature_num'], dtype='object')
#
# PATIENT_NOTES.CSV:
#        pn_num  case_num                                         pn_history
# 0           0         0  17-year-old male, has come to the student heal...
# 1           1         0  17 yo male with recurrent palpitations for the...
# 2           2         0  Dillon Cleveland is a 17 y.o. male patient wit...
# 3           3         0  a 17 yo m c/o palpitation started 3 mos ago; \...
# 4           4         0  17yo male with no pmh here for evaluation of p...
# ...       ...       ...                                                ...
# 42141   95330         9  Ms. Madden is a 20 yo female presenting w/ the...
# 42142   95331         9  A 20 YO F CAME COMPLAIN A DULL 8/10 HEADACHE T...
# 42143   95332         9  Ms. Madden is a 20yo female who presents with ...
# 42144   95333         9  Stephanie madden is a 20 year old woman compla...
# 42145   95334         9  patient is a 20 yo F who presents with a heada...
#
# [42146 rows x 3 columns] Index(['pn_num', 'case_num', 'pn_history'], dtype='object')

# %% [markdown]
# Transformers: Eliminate recurrent connections, returning to fully-connected adjacent architectures
# - Self-attention layers: Extract info from large contexts
# - When processing each item in the input, the model has access to all of the inputs up to and including the one under consideration, but no access to "information about inputs" beyond the current one
#
# It is like RNN but RNN uses sequential rather than parallalization therefore RNN is more computationally expensive.
#
# Try glove embedding space (because only 14k training samples) --> gives word vectors context

# %%
from architecture import SelfAttention
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_13581/726049075.py in <module>
# ----> 1 from architecture import SelfAttention
#
# ~/git_repos/kaggle_nbme_patient_notes/architecture.py in <module>
#       1 from turtle import forward
# ----> 2 import torch
#       3 from torch import nn
#       4
#       5
#
# ModuleNotFoundError: No module named 'torch'

# %%
notes = pd.read_csv('data/patient_notes.csv')
X = notes
train = pd.read_csv('data/train.csv')
train
# Out:
#               id  case_num  pn_num  feature_num  \
# 0      00016_000         0      16            0
# 1      00016_001         0      16            1
# 2      00016_002         0      16            2
# 3      00016_003         0      16            3
# 4      00016_004         0      16            4
# ...          ...       ...     ...          ...
# 14295  95333_912         9   95333          912
# 14296  95333_913         9   95333          913
# 14297  95333_914         9   95333          914
# 14298  95333_915         9   95333          915
# 14299  95333_916         9   95333          916
#
#                                      annotation              location
# 0              ['dad with recent heart attcak']           ['696 724']
# 1                 ['mom with "thyroid disease']           ['668 693']
# 2                            ['chest pressure']           ['203 217']
# 3          ['intermittent episodes', 'episode']  ['70 91', '176 183']
# 4      ['felt as if he were going to pass out']           ['222 258']
# ...                                         ...                   ...
# 14295                                        []                    []
# 14296                                        []                    []
# 14297                              ['photobia']           ['274 282']
# 14298                      ['no sick contacts']           ['421 437']
# 14299                      ['Subjective fever']           ['314 330']
#
# [14300 rows x 6 columns]

# %%
train.agg()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13581/91676692.py in <module>
# ----> 1 train.agg()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in aggregate(self, func, axis, *args, **kwargs)
#    8545         axis = self._get_axis_number(axis)
#    8546
# -> 8547         relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    8548
#    8549         op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/aggregation.py in reconstruct_func(func, **kwargs)
#      91         elif func is None:
#      92             # nicer error message
# ---> 93             raise TypeError("Must provide 'func' or tuples of '(column, aggfunc).")
#      94
#      95     if relabeling:
#
# TypeError: Must provide 'func' or tuples of '(column, aggfunc).

# %%
notes.iloc[16]['pn_history'][668:693]
notes
# Out:
#        pn_num  case_num                                         pn_history
# 0           0         0  17-year-old male, has come to the student heal...
# 1           1         0  17 yo male with recurrent palpitations for the...
# 2           2         0  Dillon Cleveland is a 17 y.o. male patient wit...
# 3           3         0  a 17 yo m c/o palpitation started 3 mos ago; \...
# 4           4         0  17yo male with no pmh here for evaluation of p...
# ...       ...       ...                                                ...
# 42141   95330         9  Ms. Madden is a 20 yo female presenting w/ the...
# 42142   95331         9  A 20 YO F CAME COMPLAIN A DULL 8/10 HEADACHE T...
# 42143   95332         9  Ms. Madden is a 20yo female who presents with ...
# 42144   95333         9  Stephanie madden is a 20 year old woman compla...
# 42145   95334         9  patient is a 20 yo F who presents with a heada...
#
# [42146 rows x 3 columns]

# %%
features = pd.read_csv('data/features.csv')
features
# Out:
#      feature_num  case_num                                       feature_text
# 0              0         0  Family-history-of-MI-OR-Family-history-of-myoc...
# 1              1         0                 Family-history-of-thyroid-disorder
# 2              2         0                                     Chest-pressure
# 3              3         0                              Intermittent-symptoms
# 4              4         0                                        Lightheaded
# ..           ...       ...                                                ...
# 138          912         9                        Family-history-of-migraines
# 139          913         9                                             Female
# 140          914         9                                        Photophobia
# 141          915         9                          No-known-illness-contacts
# 142          916         9                                   Subjective-fever
#
# [143 rows x 3 columns]

# %%
'asdfs'[3]
# Out:
# 'f'

# %%
train
# Out:
#               id  case_num  pn_num  feature_num  \
# 0      00016_000         0      16            0
# 1      00016_001         0      16            1
# 2      00016_002         0      16            2
# 3      00016_003         0      16            3
# 4      00016_004         0      16            4
# ...          ...       ...     ...          ...
# 14295  95333_912         9   95333          912
# 14296  95333_913         9   95333          913
# 14297  95333_914         9   95333          914
# 14298  95333_915         9   95333          915
# 14299  95333_916         9   95333          916
#
#                                      annotation              location
# 0              ['dad with recent heart attcak']           ['696 724']
# 1                 ['mom with "thyroid disease']           ['668 693']
# 2                            ['chest pressure']           ['203 217']
# 3          ['intermittent episodes', 'episode']  ['70 91', '176 183']
# 4      ['felt as if he were going to pass out']           ['222 258']
# ...                                         ...                   ...
# 14295                                        []                    []
# 14296                                        []                    []
# 14297                              ['photobia']           ['274 282']
# 14298                      ['no sick contacts']           ['421 437']
# 14299                      ['Subjective fever']           ['314 330']
#
# [14300 rows x 6 columns]

# %%
features
# Out:
#      feature_num  case_num                                       feature_text
# 0              0         0  Family-history-of-MI-OR-Family-history-of-myoc...
# 1              1         0                 Family-history-of-thyroid-disorder
# 2              2         0                                     Chest-pressure
# 3              3         0                              Intermittent-symptoms
# 4              4         0                                        Lightheaded
# ..           ...       ...                                                ...
# 138          912         9                        Family-history-of-migraines
# 139          913         9                                             Female
# 140          914         9                                        Photophobia
# 141          915         9                          No-known-illness-contacts
# 142          916         9                                   Subjective-fever
#
# [143 rows x 3 columns]

# %%
train['feature_num']
# Out:
# 143

# %%
data = train.merge(features[['feature_num', 'feature_text']], on='feature_num')
X = data['annotation']#.apply(lambda x: x.maketrans('', '', 'd'))
for x in X:
    x[0].maketrans('', '', 'd')
print(X)
# print(list(map(lambda x: x.maketran(''), X)))
# print(list(map(lambda x: [[x.replace(c, '') for c in '[]']][-1], X)))

# def cleany(x):
    
y = data['feature_text']
print(X, '\n\n', y)
# Out:
# 0        ['dad with recent heart attcak']
# 1                                      []
# 2                ['father: heart attack']
# 3                           ['Father MI']
# 4                              ['Dad-MI']
#                        ...
# 14295                ['subjective fever']
# 14296                                  []
# 14297                      ['feels warm']
# 14298                       ['Felt warm']
# 14299                ['Subjective fever']
# Name: annotation, Length: 14300, dtype: object
# 0        ['dad with recent heart attcak']
# 1                                      []
# 2                ['father: heart attack']
# 3                           ['Father MI']
# 4                              ['Dad-MI']
#                        ...
# 14295                ['subjective fever']
# 14296                                  []
# 14297                      ['feels warm']
# 14298                       ['Felt warm']
# 14299                ['Subjective fever']
# Name: annotation, Length: 14300, dtype: object
#
#  0        Family-history-of-MI-OR-Family-history-of-myoc...
# 1        Family-history-of-MI-OR-Family-history-of-myoc...
# 2        Family-history-of-MI-OR-Family-history-of-myoc...
# 3        Family-history-of-MI-OR-Family-history-of-myoc...
# 4        Family-history-of-MI-OR-Family-history-of-myoc...
#                                ...
# 14295                                     Subjective-fever
# 14296                                     Subjective-fever
# 14297                                     Subjective-fever
# 14298                                     Subjective-fever
# 14299                                     Subjective-fever
# Name: feature_text, Length: 14300, dtype: object
